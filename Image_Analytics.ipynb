# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_gsc = cv2.imread('rainy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_clr = cv2.imread('rainy.jpg')

# %%
cv2.startWindowThread()
cv2.imshow('img_clr',img_clr)
cv2.waitKey(0)
# Out:
# 233

# %%
plt.imshow(img_gsc)

# %%
plt.imshow(img_gsc,cmap='gray',interpolation='bicubic')

# %%
px = img_clr[100,100]  ## Value of the location

# %%
print(px) ## Actual colour value for the pixcel
# Out:
# [55 61 60]

# %%
img_clr[100,100] = [255,255,255]

# %%
px=img_clr[55,55]

# %%
roi = img_clr[10:250,100:150]

# %%
roi
# Out:
# array([[[ 51,  57,  56],
#         [ 51,  57,  56],
#         [ 51,  57,  56],
#         ...,
#         [ 54,  60,  59],
#         [ 59,  65,  64],
#         [ 64,  70,  69]],
#
#        [[ 51,  57,  56],
#         [ 51,  57,  56],
#         [ 51,  57,  56],
#         ...,
#         [ 53,  59,  58],
#         [ 62,  68,  67],
#         [ 68,  74,  73]],
#
#        [[ 51,  57,  56],
#         [ 51,  57,  56],
#         [ 51,  57,  56],
#         ...,
#         [ 51,  57,  56],
#         [ 59,  65,  64],
#         [ 65,  71,  70]],
#
#        ...,
#
#        [[ 80,  89,  86],
#         [ 92, 103, 100],
#         [ 91, 100,  97],
#         ...,
#         [122, 153, 126],
#         [117, 151, 120],
#         [119, 154, 120]],
#
#        [[ 84,  96,  90],
#         [ 96, 110, 104],
#         [ 92, 104,  98],
#         ...,
#         [114, 148, 118],
#         [121, 155, 124],
#         [107, 142, 108]],
#
#        [[ 76,  91,  83],
#         [ 87, 104,  95],
#         [ 84,  99,  91],
# ...

# %%
img_clr[100:150,100:150] = [255,255,255]

# %%
plt.imshow(img_clr)

# %%
rect =cv2.rectangle(img,(15,25),(200,150),(0,0,255),15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-9a55e4ad8171> in <module>()
# ----> 1 rect =cv2.rectangle(img,(15,25),(200,150),(0,0,255),15)
#
# NameError: name 'img' is not defined

# %%
circle = cv2.circle(img,(100,63), 55, (0,255,0), -1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-3bba5c55ccd4> in <module>()
# ----> 1 circle = cv2.circle(img,(100,63), 55, (0,255,0), -1)
#
# NameError: name 'img' is not defined

# %%
plt.imshow(rect)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-8d235aaed752> in <module>()
# ----> 1 plt.imshow(rect)
#
# NameError: name 'rect' is not defined

# %%
## Looking multiple images at the same time to compare 
img_2 = cv2.imread('rain2.jpg')

# %%
plt.imshow(img_2)

# %%
img_clr.shape  ## Knowing the shape of the image

# %%
img_2.shape

# %%
width = 320    ## The size of the two images should be same
height = 180
dim = (width, height)

# %%
img_clr_new = cv2.resize(img_clr, dim, interpolation = cv2.INTER_AREA) ## Changing the size of the image

# %%
img_clr_new.shape

# %%
add = img_clr_new + img_2  ## Adding the two images

# %%
plt.imshow(add)

# %%
weighted = cv2.addWeighted(img_clr_new,0.6,img_2,0.4,0) ## How much weight we want to give to each image

# %%
plt.imshow(weighted)

# %%
## Another way of making one image equal in size to another image (Trying to apply logo under arithematic operation)
rows,cols,channels=img_2.shape
roi = img_clr[0:rows,0:cols]

# %%
img2 = cv2.imread('niitLogo.png')
plt.imshow(img2)

# %%
# I want to put logo on top-left corner, So I create a ROI
rows,cols,channels=img_2.shape
roi = img_clr[0:rows,0:cols]

# Now create a mask of logo and create its inverse mask
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)

# %%
# add a threshold
ret, mask = cv2.threshold(img2gray, 220, 255, cv2.THRESH_BINARY_INV)

mask_inv = cv2.bitwise_not(mask)

# %%
# Take only region of logo from logo image 
img2_fg = cv2.bitwise_and(img2,img2,mask = mask)

# %%
## Apply Simple threshold 
retval, threshold = cv2.threshold(img, 10, 255, cv2.THRESH_BINARY)

# %%
manu = cv2.imread('manuscript.jpg')

# %%
plt.imshow(manu)

# %%
import cv2 
import numpy as np
cv2.startWindowThread()
grayscaled = cv2.cvtColor(manu,cv2.COLOR_BGR2GRAY)
retval, threshold = cv2.threshold(grayscaled, 10, 255, cv2.THRESH_BINARY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-dc0f5c71b1b8> in <module>()
#       2 import numpy as np
#       3 cv2.startWindowThread()
# ----> 4 grayscaled = cv2.cvtColor(manu,cv2.COLOR_BGR2GRAY)
#       5 retval, threshold = cv2.threshold(grayscaled, 10, 255, cv2.THRESH_BINARY)
#
# NameError: name 'manu' is not defined

# %%
cv2.imshow('prev',threshold)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e44cb1e64733> in <module>()
# ----> 1 cv2.imshow('prev',threshold)
#       2 cv2.waitKey(0)
#
# NameError: name 'threshold' is not defined

# %%
th = cv2.adaptiveThreshold(grayscaled, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 115, 1)

# %%
plt.imshow(th)

# %%
retval2,threshold2 = cv2.threshold(grayscaled,125,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# %%
plt.imshow(threshold2)

# %%
## Color Filtering 

img_cap = cv2.imread('redcap_boy.jpg')

# %%
plt.imshow(img_cap)

# %%
hsv = cv2.cvtColor(img_cap, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(hsv)

# %%
lower_red = np.array([30,150,50])
upper_red = np.array([255,255,180])

# %%
mask = cv2.inRange(hsv, lower_red, upper_red)

# %%
res = cv2.bitwise_and(hsv,hsv, mask= mask)

# %%
plt.imshow(res)

# %%
while(1):
    
    frame = cv2.imread('redcap_boy.jpg') _
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    lower_red = np.array([30,150,50])
    upper_red = np.array([255,255,180])
    
    mask = cv2.inRange(hsv, lower_red, upper_red)
    res = cv2.bitwise_and(frame,frame, mask= mask)

    cv2.imshow('frame',frame)
    cv2.imshow('mask',mask)
    cv2.imshow('res',res)
    
    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()
cap.release()
# Out:
#   File "<ipython-input-1-301975500c9b>", line 3
#     frame = cv2.imread('redcap_boy.jpg') _
#                                          ^
# SyntaxError: invalid syntax
